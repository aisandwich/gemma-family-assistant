# %%
import json
import requests
import time
import re
from typing import Dict, List, Any

class AyurvedaQAGenerator:
    def __init__(self, ollama_url="http://localhost:11434", model_name="gemma3n:e4b"):
        self.ollama_url = ollama_url
        self.model_name = model_name
        self.generated_qa = []
        
    def format_herb_data(self, herb_data: Dict) -> str:
        """Format herb data for prompt"""
        herb_name = herb_data.get("herb", "")
        scientific_name = herb_data.get("scientific_name", "")
        
        # Filter and format ailments
        uses_text = ""
        for ailment in herb_data.get("ailments", []):
            ailment_name = ailment.get("name", "")
            remedy = ailment.get("remedies", "")
            
            # Skip malformed entries
            if len(ailment_name) > 3 and len(remedy) > 10:
                # Skip entries that are clearly OCR errors or scientific names
                if not ailment_name.startswith("(") and "officinale" not in ailment_name:
                    uses_text += f"- {ailment_name}: {remedy}\n"
        
        return herb_name, scientific_name, uses_text
    
    def generate_herb_prompt(self, herb_data: Dict) -> str:
        """Generate dynamic prompt for each herb"""
        herb_name, scientific_name, uses_text = self.format_herb_data(herb_data)
        
        prompt = f"""You are creating educational Q&A pairs for a traditional medicine app that helps Indian families with home remedies. Based on this Ayurvedic herb information, generate exactly 15 question-answer pairs that would help a mother learn about natural treatments.
        Each question must include a reference to Ayurveda, Ayurvedic remedy, or home remedy context.

Herb Information:
Herb: {herb_name}
Scientific Name: {scientific_name}
Traditional Uses:
{uses_text}

Generate 15 Q&A pairs in this format:
Q1: [practical question a mother might ask]
A1: [helpful answer with specific remedy and dosage]

Q2: [another practical question]
A2: [helpful answer with specific remedy and dosage]

Continue this pattern for all 15 pairs. Cover different scenarios: family health issues, children's ailments, preparation methods, dosages, safety warnings, and prevention. Make questions natural and answers practical for home use with proper traditional Indian context."""
        
        return prompt
    
    def query_ollama(self, prompt: str, max_retries: int = 3) -> str:
        """Query Ollama API with retry logic"""
        for attempt in range(max_retries):
            try:
                response = requests.post(
                    f"{self.ollama_url}/api/generate",
                    json={
                        "model": self.model_name,
                        "prompt": prompt,
                        "stream": False,
                        "options": {
                            "temperature": 0.7,
                            "top_p": 0.9,
                            "max_tokens": 2000
                        }
                    },
                    timeout=120  # 2 minutes timeout
                )
                
                if response.status_code == 200:
                    result = response.json()
                    return result.get("response", "")
                else:
                    print(f"HTTP Error {response.status_code}: {response.text}")
                    
            except Exception as e:
                print(f"Attempt {attempt + 1} failed: {e}")
                if attempt < max_retries - 1:
                    time.sleep(5)  # Wait 5 seconds before retry
                
        return ""
    
    def parse_qa_response(self, response: str) -> List[Dict[str, str]]:
        """Parse Q&A pairs from Gemma response"""
        qa_pairs = []
        
        # Split by Q patterns
        questions = re.split(r'Q\d+:', response)[1:]  # Skip first empty split
        
        for i, q_section in enumerate(questions, 1):
            # Split question and answer
            parts = re.split(r'A\d+:', q_section, 1)
            if len(parts) == 2:
                question = parts[0].strip()
                answer = parts[1].strip()
                
                # Clean up answer (remove next question if present)
                answer = re.split(r'Q\d+:', answer)[0].strip()
                
                if question and answer:
                    qa_pairs.append({
                        "question": question,
                        "answer": answer
                    })
        
        return qa_pairs
    
    def generate_qa_for_herb(self, herb_data: Dict) -> Dict:
        """Generate Q&A pairs for a single herb"""
        herb_name, scientific_name, uses_text = self.format_herb_data(herb_data)
        
        print(f"\n🌿 Processing herb: {herb_name}")
        
        # Skip if no valid uses found
        if not uses_text.strip():
            print(f"⚠️  Skipping {herb_name} - no valid ailments found")
            return None
        
        # Generate prompt
        prompt = self.generate_herb_prompt(herb_data)
        
        # Query Ollama
        response = self.query_ollama(prompt)
        
        if not response:
            print(f"❌ Failed to generate Q&A for {herb_name}")
            return None
        
        # Parse response
        qa_pairs = self.parse_qa_response(response)
        
        if not qa_pairs:
            print(f"❌ Failed to parse Q&A for {herb_name}")
            return None
        
        print(f"✅ Generated {len(qa_pairs)} Q&A pairs for {herb_name}")
        
        return {
            "herb": herb_name,
            "scientific_name": scientific_name,
            "qa_pairs": qa_pairs,
            "source": "Ayurveda",
            "page": herb_data.get("page", ""),
            "ailment_count": len([a for a in herb_data.get("ailments", []) if len(a.get("name", "")) > 3])
        }
    
    def process_all_herbs(self, json_file_path: str, output_file_path: str):
        """Process all herbs in the JSON file"""
        print(f"📚 Loading data from: {json_file_path}")
        
        try:
            with open(json_file_path, 'r', encoding='utf-8') as f:
                herbs_data = json.load(f)
        except Exception as e:
            print(f"❌ Error loading JSON file: {e}")
            return
        
        print(f"📊 Found {len(herbs_data)} herbs to process")
        
        all_qa_data = []
        successful_herbs = 0
        
        for i, herb_data in enumerate(herbs_data):
            print(f"\n📍 Progress: {i+1}/{len(herbs_data)}")
            
            # Generate Q&A for this herb
            herb_qa = self.generate_qa_for_herb(herb_data)
            
            if herb_qa:
                all_qa_data.append(herb_qa)
                successful_herbs += 1
            
            # Add delay between requests to be nice to the API
            time.sleep(2)
        
        # Save results
        try:
            with open(output_file_path, 'w', encoding='utf-8') as f:
                json.dump(all_qa_data, f, indent=2, ensure_ascii=False)
            
            print(f"\n🎉 SUCCESS!")
            print(f"✅ Processed {successful_herbs}/{len(herbs_data)} herbs successfully")
            print(f"💾 Saved to: {output_file_path}")
            
            # Calculate total Q&A pairs
            total_qa = sum(len(herb["qa_pairs"]) for herb in all_qa_data)
            print(f"📊 Total Q&A pairs generated: {total_qa}")
            
        except Exception as e:
            print(f"❌ Error saving results: {e}")

# %%
input_file = "/Users/saikumarallaka/kaggle/gemma_3n_impact_challenge/datasets/ayurveda/ayurveda_structured_data_extract.json"
output_file = "/Users/saikumarallaka/kaggle/gemma_3n_impact_challenge/datasets/ayurveda/ayurveda_qa_dataset.json"

# %%
qa_generator = AyurvedaQAGenerator()

# %%
with open(input_file, 'r', encoding='utf-8') as f:
        herbs_data = json.load(f)

# %%
test_result = qa_generator.generate_qa_for_herb(herbs_data[0])
# Out:
# 🌿 Processing herb: Adrak/ Sonth
# ✅ Generated 15 Q&A pairs for Adrak/ Sonth

# %%
test_result
# Out:
# {'herb': 'Adrak/ Sonth',
#  'scientific_name': '( Zingiber officinale',
#  'qa_pairs': [{'question': "My child has a persistent cough and cold. In Ayurveda, what's a natural home remedy using Adrak that can help soothe their respiratory system?",
#    'answer': 'In Ayurveda, Adrak (ginger) is excellent for cough and cold. Give your child 2-5 gm of dry ginger powder mixed with jaggery, three times a day in divided doses. You can also prepare a 10ml decoction from a piece of ginger to give in the morning to help prevent recurrent attacks.'},
#   {'question': 'My mother-in-law complains of stomach pain and indigestion. Can Adrak be used as a home remedy in Ayurveda for this?',
#    'answer': 'Yes, Adrak is traditionally used for indigestion. She can take 5 gm of crushed Adrak rhizome with salt or jaggery twice daily, especially before meals. This helps stimulate digestion.'},
#   {'question': 'My voice is hoarse. Does Ayurveda recommend any home remedy involving Adrak for this?',
#    'answer': 'Yes, for hoarseness, Ayurveda suggests using Adrak. She can take 1-3 gm of dry Adrak powder mixed with honey in three divided doses. This can help alleviate the throat inflammation.'},
#   {'question': 'My child is experiencing aches and pains after playing. Can I use Adrak for this as a natural remedy?',
#    'answer': 'Absolutely. In Ayurveda, a decoction of Adrak is beneficial for aches and pains. Prepare a 10-20 ml decoction from 2 gm of dry Adrak and give it twice a day.'},
#   {'question': "What's the best way to prepare Adrak for a cold and cough remedy, keeping in mind traditional Ayurvedic practices?",
#    'answer': 'For cold and cough, the best approach is to use dry Adrak powder with jaggery. Mix 2-5 gm of powder with jaggery and give it thrice a day in divided doses. A morning decoction of ginger (10ml) is also very effective for prevention.'},
#   {'question': 'My forehead is aching. Can a simple home remedy using Adrak help with this headache, according to Ayurveda?',
#    'answer': 'Yes, a warm paste of Adrak can be applied to the forehead up to three times a day to relieve headaches. This is a common Ayurvedic practice for headache relief.'},
#   {'question': 'My child has ear pain. Is it safe to use Adrak as a home remedy for this in Ayurveda?',
#    'answer': 'While Adrak is beneficial, do not use it for ear pain if there is any discharge from the ear. However, for mild ear pain without discharge, you can instill 2-4 drops of fresh, warm Adrak juice into the ear.'},
#   {'question': 'Can I give Adrak to my child even if they are constipated? Is it considered good for digestive balance in Ayurveda?',
#    'answer': "While Adrak is generally good for digestion, it's not typically recommended for constipation. It can sometimes stimulate bowel movements. If your child is constipated, it's best to consult a healthcare professional."},
#   {'question': "Are there any specific times of the day when it's best to consume Adrak for its Ayurvedic benefits?",
#    'answer': "Traditionally, it's recommended to consume Adrak before meals to aid digestion. However, it can be taken at any time for its other benefits like cold and cough relief."},
#   {'question': 'Is there anything I should be cautious about when using Adrak as a home remedy, especially for children?',
#    'answer': 'While generally safe, avoid giving large amounts of Adrak to children. It can cause mild stomach upset in some cases. Also, be mindful of any allergies your child might have.'},
#   {'question': 'Can I combine Adrak with other common Ayurvedic ingredients for a more potent home remedy?',
#    'answer': 'Yes, Adrak is often combined with honey and jaggery in Ayurvedic remedies for cough, cold, and general well-being. These combinations enhance its therapeutic properties.'},
#   {'question': 'If my child has a fever along with a cold, can Adrak help?',
#    'answer': 'Yes, Adrak can be helpful for managing the symptoms of a cold and fever. Give 2-5 gm of Adrak powder with jaggery thrice a day and ensure they stay hydrated.'},
#   {'question': 'How long should I continue giving Adrak to my child for a cold or cough?',
#    'answer': "Continue giving Adrak as long as the cold or cough symptoms persist, typically for 3-5 days. If the symptoms don't improve, consult a healthcare professional."},
#   {'question': 'Is there a specific type of Adrak (e.g., older or younger) that is better for home remedies in Ayurveda?',
#    'answer': 'Generally, the older the Adrak rhizome, the more potent its medicinal properties are in Ayurveda. However, fresh Adrak is always preferred for immediate use in remedies.'},
#   {'question': 'Can using Adrak as a home remedy for a recurring cold be a preventative measure according to Ayurvedic principles?',
#    'answer': 'Yes, consuming 10ml of Adrak decoction every morning is considered a preventative measure in Ayurveda to help prevent recurrent cold attacks. This strengthens the immune system.'}],
#  'source': 'Ayurveda',
#  'page': 8,
#  'ailment_count': 8}

# %%
    # Initialize generator
    qa_generator = AyurvedaQAGenerator()
    
    # Test with first herb only (for debugging)
    print("🧪 Testing with first herb...")
    try:
        with open(input_file, 'r', encoding='utf-8') as f:
            herbs_data = json.load(f)
        
        if herbs_data:
            test_result = qa_generator.generate_qa_for_herb(herbs_data[0])
            if test_result:
                print(f"✅ Test successful! Generated {len(test_result['qa_pairs'])} Q&A pairs")
                
                # Show sample Q&A
                if test_result['qa_pairs']:
                    sample_qa = test_result['qa_pairs'][0]
                    print(f"\n📝 Sample Q&A:")
                    print(f"Q: {sample_qa['question']}")
                    print(f"A: {sample_qa['answer'][:150]}...")
                
                # Ask user if they want to continue with all herbs
                continue_all = input("\n🤔 Continue with all herbs? (y/n): ").lower().strip()
                if continue_all == 'y':
                    qa_generator.process_all_herbs(input_file, output_file)
                else:
                    print("✋ Stopped after test. Adjust settings if needed.")
            else:
                print("❌ Test failed. Check your Ollama setup and model.")
        
    except Exception as e:
        print(f"❌ Error: {e}")

if __name__ == "__main__":
    main()

# %%
# Generate Q&A for all herbs
all_qa_results = []

for herb in herbs_data:
    qa_result = qa_generator.generate_qa_for_herb(herb)
    all_qa_results.append(qa_result)
# Out:
# 🌿 Processing herb: Adrak/ Sonth
# ✅ Generated 15 Q&A pairs for Adrak/ Sonth
#
# 🌿 Processing herb: ATYAIN
# ✅ Generated 15 Q&A pairs for ATYAIN
#
# 🌿 Processing herb: ANAR
# ✅ Generated 15 Q&A pairs for ANAR
#
# 🌿 Processing herb: AMLA
# ✅ Generated 15 Q&A pairs for AMLA
#
# 🌿 Processing herb: DALCHINI
# ✅ Generated 15 Q&A pairs for DALCHINI
#
# 🌿 Processing herb: DHANIA
# ✅ Generated 15 Q&A pairs for DHANIA
#
# 🌿 Processing herb: ELAICHI
# ✅ Generated 15 Q&A pairs for ELAICHI
#
# 🌿 Processing herb: GHEE
# ✅ Generated 15 Q&A pairs for GHEE
#
# 🌿 Processing herb: HALDI
# ✅ Generated 15 Q&A pairs for HALDI
#
# 🌿 Processing herb: HING
# ✅ Generated 15 Q&A pairs for HING
#
# 🌿 Processing herb: TAYPHAL
# ✅ Generated 15 Q&A pairs for TAYPHAL
#
# 🌿 Processing herb:
# ✅ Generated 15 Q&A pairs for
#
# 🌿 Processing herb: KALIMIRACH
# ✅ Generated 15 Q&A pairs for KALIMIRACH
#
# 🌿 Processing herb: KARELA
# ✅ Generated 15 Q&A pairs for KARELA
#
# 🌿 Processing herb: LAHSUN
# ✅ Generated 15 Q&A pairs for LAHSUN
#
# 🌿 Processing herb: LAUNG
# ✅ Generated 15 Q&A pairs for LAUNG
#
# 🌿 Processing herb: M APHUf Honey)
# ✅ Generated 15 Q&A pairs for M APHUf Honey)
#
# 🌿 Processing herb: METHI
# ✅ Generated 15 Q&A pairs for METHI
#
# 🌿 Processing herb: NARIYAL
# ✅ Generated 15 Q&A pairs for NARIYAL
#
# 🌿 Processing herb: NEEM
# ✅ Generated 15 Q&A pairs for NEEM
#
# 🌿 Processing herb: NIMBU
# ✅ Generated 15 Q&A pairs for NIMBU
#
# 🌿 Processing herb: PYAT
# ✅ Generated 15 Q&A pairs for PYAT
#
# 🌿 Processing herb: PIPPALI
# ✅ Generated 15 Q&A pairs for PIPPALI
#
# 🌿 Processing herb: SAUNF
# ✅ Generated 15 Q&A pairs for SAUNF
#
# 🌿 Processing herb: TULSI
# ✅ Generated 15 Q&A pairs for TULSI

# %%
1
# Out:
# 1

# %%
all_qa_results[10]
# Out:
# {'herb': 'TAYPHAL',
#  'scientific_name': '(Myristica fragmns',
#  'qa_pairs': [{'question': "My child is suffering from diarrhea. I've heard of natural remedies in Ayurveda. Can you tell me how Tayphal can help?",
#    'answer': 'Yes, in Ayurveda, Tayphal is known to help with diarrhea in children. You can give a pinch of Tayphal powder or fruit rubbed on a clean surface, mixed with milk or water, 3-4 times a day.'},
#   {'question': 'My daughter has been very irritable lately, especially during her periods. Is there a home remedy using Tayphal that might help calm her down?',
#    'answer': "Absolutely. Tayphal has mild sedative properties. Give her 1-2 pinches of Tayphal powder mixed with milk, 3-4 times a day, if she's restless and irritable. This is a common Ayurvedic practice for calming the mind."},
#   {'question': "I've noticed some dark spots on my face, particularly around my eyes. Is this common, and can Tayphal help?",
#    'answer': 'Yes, dark pigmentation is often seen in women, especially around menopause. In Ayurveda, rubbing Tayphal in milk and applying it to these areas is a traditional remedy that can be beneficial.'},
#   {'question': "My child has a tummy ache, and I suspect it's related to a recent bout of diarrhea. What can I do using a home remedy?",
#    'answer': 'If the abdominal pain is due to diarrhea, you can give your child 2 grams of Tayphal powder mixed with warm water, 4-5 times a day. This helps reduce intestinal motility and ease the pain, a principle in Ayurvedic treatment.'},
#   {'question': 'How should I prepare Tayphal for my child to make it easier for them to consume?',
#    'answer': 'You can either grind Tayphal powder directly and mix it with milk or water, or gently rub the fruit on a clean surface and then mix the rubbed substance with milk or water.'},
#   {'question': "Is there a specific time of day that's best to give Tayphal to my child for diarrhea?",
#    'answer': "It's generally recommended to give Tayphal remedies to a child as soon as they notice symptoms of diarrhea, and you can repeat the dosage every 3-4 hours as needed."},
#   {'question': "Can I use Tayphal for adults experiencing irritability or restlessness? What's the recommended dosage?",
#    'answer': "Yes, adults can also benefit from Tayphal's calming properties. A dosage of 1-2 pinches of powder mixed with milk, 3-4 times a day, can help with irritability and restlessness."},
#   {'question': 'Are there any potential side effects or precautions I should be aware of when using Tayphal as a home remedy?',
#    'answer': "While generally safe in small amounts, it's always wise to start with a small dose to check for any allergic reactions. Avoid giving it to very young infants without consulting a healthcare practitioner."},
#   {'question': 'Can Tayphal be used as a preventative measure against diarrhea in children?',
#    'answer': 'While not a strict preventative, using Tayphal in small amounts during travel or periods of increased hygiene concerns can be considered a traditional Ayurvedic approach to support digestive health.'},
#   {'question': "I've heard Tayphal is good for skin. Can it help with other skin conditions besides pigmentation?",
#    'answer': "Traditionally, Tayphal is known for its benefits in addressing pigmentation. However, for other skin conditions, it's best to consult with an Ayurvedic practitioner for a tailored remedy."},
#   {'question': 'Can I use the Tayphal fruit directly instead of the powder?',
#    'answer': 'Yes, you can use the fruit. Gently rub the outside of the Tayphal fruit on a clean surface to extract the essence, and then mix this rubbed substance with milk or water for your child.'},
#   {'question': 'Is there a way to incorporate Tayphal into everyday Indian cooking for its health benefits?',
#    'answer': 'While not a common ingredient in everyday cooking, a very small amount of Tayphal can be used as a spice in certain savory dishes, which is a traditional Ayurvedic practice for incorporating its benefits.'},
#   {'question': 'If my child refuses to drink milk, can I give the Tayphal remedy with water?',
#    'answer': "Yes, you can definitely mix the Tayphal powder with warm water if your child doesn't like milk. Ensure the water is warm, as this can enhance its efficacy."},
#   {'question': 'Can Tayphal be combined with other Ayurvedic remedies for a more comprehensive treatment?',
#    'answer': "It's always best to consult with an Ayurvedic practitioner before combining Tayphal with other remedies to ensure there are no adverse interactions."},
#   {'question': 'Where can I find pure and authentic Tayphal powder for home use?',
#    'answer': 'You can find pure Tayphal powder at reputable Ayurvedic stores or online retailers that specialize in traditional Indian herbal products. Ensure the product is from a trusted source.'}],
#  'source': 'Ayurveda',
#  'page': 18,
#  'ailment_count': 4}

# %%
with open("../datasets/ayurveda/ayurveda_qa_dataset.json", 'w', encoding='utf-8') as f:
    json.dump(all_qa_results, f, ensure_ascii=False, indent=2)
