# %%
import json
import requests
import time
import re
from typing import Dict, List, Any
from collections import defaultdict

class EducationalQAGenerator:
    def __init__(self, ollama_url="http://localhost:11434", model_name="gemma3n:e4b"):
        self.ollama_url = ollama_url
        self.model_name = model_name
        self.generated_qa = []
        
    def format_educational_data(self, record: Dict) -> tuple:
        """Format educational data for prompt"""
        main_heading = record.get("main_heading", "")
        sub_heading = record.get("sub_heading", "")
        content = record.get("content", "")
        page_start = record.get("page_start", "")
        page_end = record.get("page_end", "")
        
        return main_heading, sub_heading, content, page_start, page_end
    
    def generate_subtopic_prompt(self, record: Dict) -> str:
        """Generate prompt for sub-topic level (5 Q&A pairs)"""
        main_heading, sub_heading, content, page_start, page_end = self.format_educational_data(record)
        
        prompt = f"""You are creating educational Q&A pairs for a learning app that helps students understand academic concepts. Based on this educational content, generate exactly 5 question-answer pairs that would help a student learn about this topic.

Each question must include clear reference to the subject matter and be educational in nature.

Educational Content:
Main Topic: {main_heading}
Sub-topic: {sub_heading}
Pages: {page_start}-{page_end}
Content: {content}

Generate 5 Q&A pairs in this format:
Q1: [clear educational question about the content]
A1: [comprehensive answer with specific information]

Q2: [another educational question about the content]
A2: [comprehensive answer with specific information]

Q3: [question about key concepts or definitions]
A3: [comprehensive answer with specific information]

Q4: [question about examples or applications]
A4: [comprehensive answer with specific information]

Q5: [question about classification or comparison]
A5: [comprehensive answer with specific information]

Make questions clear and educational. Cover different aspects: definitions, examples, classifications, processes, and practical applications. Make answers comprehensive and student-friendly."""
        
        return prompt
    
    def generate_topic_prompt(self, topic_records: List[Dict]) -> str:
        """Generate prompt for topic level (30 Q&A pairs from all sub-topics)"""
        if not topic_records:
            return ""
            
        main_heading = topic_records[0].get("main_heading", "")
        
        # Combine all content from sub-topics
        combined_content = ""
        subtopics = []
        
        for record in topic_records:
            sub_heading = record.get("sub_heading", "")
            content = record.get("content", "")
            subtopics.append(sub_heading)
            combined_content += f"\n\n{sub_heading}:\n{content}"
        
        prompt = f"""You are creating comprehensive educational Q&A pairs for a learning app. Based on this complete topic content covering multiple sub-topics, generate exactly 30 question-answer pairs that would help students master this entire topic.

Each question must be educational and cover the breadth of the topic comprehensively.

Main Topic: {main_heading}
Sub-topics covered: {', '.join(subtopics)}

Complete Content: {combined_content}

Generate 30 Q&A pairs in this format:
Q1: [comprehensive question about the topic]
A1: [detailed answer with specific information]

Q2: [another comprehensive question]
A2: [detailed answer with specific information]

Continue this pattern for all 30 pairs. Cover the full scope of the topic including:
- Key definitions and concepts
- Classifications and types
- Processes and procedures
- Examples and applications
- Comparisons and relationships
- Problem-solving scenarios
- Practical applications
- Cross-connections between sub-topics

Make questions comprehensive and answers detailed for complete topic mastery."""
        
        return prompt
    
    def query_ollama(self, prompt: str, max_retries: int = 10) -> str:
        """Query Ollama API with retry logic"""
        for attempt in range(max_retries):
            try:
                response = requests.post(
                    f"{self.ollama_url}/api/generate",
                    json={
                        "model": self.model_name,
                        "prompt": prompt,
                        "stream": False,
                        "options": {
                            "temperature": 0.7,
                            "top_p": 0.9,
                            "max_tokens": 3000  # Increased for 30 Q&A pairs
                        }
                    },
                    timeout=180  # 3 minutes timeout for longer responses
                )
                
                if response.status_code == 200:
                    result = response.json()
                    return result.get("response", "")
                else:
                    print(f"HTTP Error {response.status_code}: {response.text}")
                    
            except Exception as e:
                print(f"Attempt {attempt + 1} failed: {e}")
                if attempt < max_retries - 1:
                    time.sleep(60)
                
        return ""
    
    def parse_qa_response(self, response: str) -> List[Dict[str, str]]:
        """Parse Q&A pairs from response"""
        qa_pairs = []
        
        # Split by Q patterns
        questions = re.split(r'Q\d+:', response)[1:]
        
        for i, q_section in enumerate(questions, 1):
            # Split question and answer
            parts = re.split(r'A\d+:', q_section, 1)
            if len(parts) == 2:
                question = parts[0].strip()
                answer = parts[1].strip()
                
                # Clean up answer (remove next question if present)
                answer = re.split(r'Q\d+:', answer)[0].strip()
                
                if question and answer:
                    qa_pairs.append({
                        "question": question,
                        "answer": answer
                    })
        
        return qa_pairs
    
    def generate_qa_for_subtopic(self, record: Dict) -> Dict:
        """Generate 5 Q&A pairs for a single sub-topic"""
        main_heading, sub_heading, content, page_start, page_end = self.format_educational_data(record)
        
        print(f"\n📖 Processing sub-topic: {sub_heading}")
        
        if not content.strip():
            print(f"⚠️  Skipping {sub_heading} - no content found")
            return None
        
        prompt = self.generate_subtopic_prompt(record)
        response = self.query_ollama(prompt)
        
        if not response:
            print(f"❌ Failed to generate Q&A for {sub_heading}")
            return None
        
        qa_pairs = self.parse_qa_response(response)
        
        if not qa_pairs:
            print(f"❌ Failed to parse Q&A for {sub_heading}")
            return None
        
        print(f"✅ Generated {len(qa_pairs)} Q&A pairs for {sub_heading}")
        
        return {
            "main_heading": main_heading,
            "sub_heading": sub_heading,
            "qa_pairs": qa_pairs,
            "level": "subtopic",
            "page_range": f"{page_start}-{page_end}",
            "content_length": len(content)
        }
    
    def generate_qa_for_topic(self, topic_records: List[Dict]) -> Dict:
        """Generate 30 Q&A pairs for entire topic (combining all sub-topics)"""
        if not topic_records:
            return None
            
        main_heading = topic_records[0].get("main_heading", "")
        print(f"\n📚 Processing main topic: {main_heading}")
        print(f"📋 Combining {len(topic_records)} sub-topics")
        
        prompt = self.generate_topic_prompt(topic_records)
        response = self.query_ollama(prompt)
        
        if not response:
            print(f"❌ Failed to generate Q&A for topic {main_heading}")
            return None
        
        qa_pairs = self.parse_qa_response(response)
        
        if not qa_pairs:
            print(f"❌ Failed to parse Q&A for topic {main_heading}")
            return None
        
        print(f"✅ Generated {len(qa_pairs)} Q&A pairs for topic {main_heading}")
        
        subtopic_list = [record.get("sub_heading", "") for record in topic_records]
        
        return {
            "main_heading": main_heading,
            "sub_headings": subtopic_list,
            "qa_pairs": qa_pairs,
            "level": "topic",
            "subtopic_count": len(topic_records),
            "total_content_length": sum(len(record.get("content", "")) for record in topic_records)
        }
    
    def process_all_records(self, json_file_path: str, output_file_path: str):
        """Process all records - generate both sub-topic and topic level Q&A"""
        print(f"📚 Loading data from: {json_file_path}")
        
        try:
            with open(json_file_path, 'r', encoding='utf-8') as f:
                records = json.load(f)
        except Exception as e:
            print(f"❌ Error loading JSON file: {e}")
            return
        
        print(f"📊 Found {len(records)} records to process")
        
        # Group records by main_heading
        topics_grouped = defaultdict(list)
        for record in records:
            main_heading = record.get("main_heading", "Unknown")
            topics_grouped[main_heading].append(record)
        
        print(f"📋 Found {len(topics_grouped)} main topics")
        
        all_qa_data = []
        successful_subtopics = 0
        successful_topics = 0
        
        # Process each main topic
        for main_heading, topic_records in topics_grouped.items():
            print(f"\n🎯 Processing main topic: {main_heading}")
            print(f"   └── Contains {len(topic_records)} sub-topics")
            
            # 1. Generate Q&A for each sub-topic (5 each)
            for i, record in enumerate(topic_records):
                print(f"\n📍 Sub-topic progress: {i+1}/{len(topic_records)}")
                
                subtopic_qa = self.generate_qa_for_subtopic(record)
                if subtopic_qa:
                    all_qa_data.append(subtopic_qa)
                    successful_subtopics += 1
                
                time.sleep(2)  # Rate limiting
            
            # 2. Generate Q&A for entire topic (30 total)
            topic_qa = self.generate_qa_for_topic(topic_records)
            if topic_qa:
                all_qa_data.append(topic_qa)
                successful_topics += 1
            
            time.sleep(3)  # Longer pause between topics
        
        # Save results
        try:
            with open(output_file_path, 'w', encoding='utf-8') as f:
                json.dump(all_qa_data, f, indent=2, ensure_ascii=False)
            
            print(f"\n🎉 SUCCESS!")
            print(f"✅ Processed {successful_subtopics} sub-topics successfully")
            print(f"✅ Processed {successful_topics} main topics successfully")
            print(f"💾 Saved to: {output_file_path}")
            
            # Calculate total Q&A pairs
            total_qa = sum(len(item["qa_pairs"]) for item in all_qa_data)
            print(f"📊 Total Q&A pairs generated: {total_qa}")
            
        except Exception as e:
            print(f"❌ Error saving results: {e}")

# %% [markdown]
# ## test

# %%
# # Usage example:
# if __name__ == "__main__":
qa_generator = EducationalQAGenerator()

    
# Or test single sub-topic:
sample_record = {
    "main_heading": "CROP PRODUCTION AND MANAGEMENT",
    "sub_heading": "1.1 Agricultural Practices",
    "content": " Till 10,000 B.C.E. people were nomadic. They were wandering in groups from place to place in search of food and shelter. They ate raw fruits and vegetables and started hunting animals for food. Later, they could cultivate land and produce rice, wheat and other food crops. Thus, was born ‘Agriculture’. When plants of the same kind are cultivated at one place on a large scale, it is called a  crop . For example, crop of wheat means that all the plants grown in a field are that of wheat. You already know that crops are of different types like cereals, vegetables and fruits. These can be classified on the basis of the season in which they grow. India is a vast country. The climatic conditions like temperature, humidity and rainfall vary from one region to another. Accordingly, there is a rich You have learnt that all living organisms require food. Plants can make their food themselves. Can you recall how green plants synthesise their own food? Animals including humans can not make their own food. So, where do animals get their food from? But, first of all why do we have to eat food? You already know that energy from the food is utilised by organisms for carrying out their various body functions, such as digestion, respiration and excretion. We get our food from plants, or animals, or both. Since we all need food, how can we provide food to a large number of people in our country? Food has to be produced on a large scale. I want to know where and how we use these tools. 2018-19 SCIENCE 2 variety of crops grown in different parts of the country. Despite this diversity, two broad cropping patterns can be identified. These are: (i) Kharif Crops :  The crops which are sown in the rainy season are called kharif crops. The rainy season in India is generally from June to September. Paddy, maize, soyabean, groundnut and cotton are kharif crops. (ii) Rabi Crops :  The crops grown in the winter season (October to March) are called rabi crops. Examples of rabi crops are wheat, gram, pea, mustard and linseed. Besides these, pulses and vegetables are grown during summer at many places.",
    "page_start": 14,
    "page_end": 15
}

test_result = qa_generator.generate_qa_for_subtopic(sample_record)
# Out:
# 📖 Processing sub-topic: 1.1 Agricultural Practices
# ✅ Generated 5 Q&A pairs for 1.1 Agricultural Practices

# %%
test_result

# %%
test_result = qa_generator.generate_qa_for_topic([sample_record])
# Out:
# 📚 Processing main topic: CROP PRODUCTION AND MANAGEMENT
# 📋 Combining 1 sub-topics
# ✅ Generated 30 Q&A pairs for topic CROP PRODUCTION AND MANAGEMENT

# %%
test_result

# %%
# Initialize the generator
qa_generator = EducationalQAGenerator()
    
# Process all depression records
input_file = "/Users/saikumarallaka/kaggle/gemma_3n_impact_challenge/datasets/education/education_structured_data_extract.json"  # Your input file
output_file = "/Users/saikumarallaka/kaggle/gemma_3n_impact_challenge/datasets/education/education_qa_dataset.json"  # Output file

qa_generator.process_all_records(input_file, output_file)
# Out:
# 📚 Loading data from: /Users/saikumarallaka/kaggle/gemma_3n_impact_challenge/datasets/education/education_structured_data_extract.json
# 📊 Found 137 records to process
# 📋 Found 18 main topics
#
# 🎯 Processing main topic: CROP PRODUCTION   AND MANAGEMENT
#    └── Contains 11 sub-topics
#
# 📍 Sub-topic progress: 1/11
#
# 📖 Processing sub-topic: 1.1 Agricultural Practices
# ✅ Generated 5 Q&A pairs for 1.1 Agricultural Practices
#
# 📍 Sub-topic progress: 2/11
#
# 📖 Processing sub-topic: 1.2 Basic Practices of Crop Production
# ✅ Generated 5 Q&A pairs for 1.2 Basic Practices of Crop Production
#
# 📍 Sub-topic progress: 3/11
#
# 📖 Processing sub-topic: 1.3 Preparation of Soil
# ✅ Generated 5 Q&A pairs for 1.3 Preparation of Soil
#
# 📍 Sub-topic progress: 4/11
#
# 📖 Processing sub-topic: 1.4 Sowing
# ✅ Generated 5 Q&A pairs for 1.4 Sowing
#
# 📍 Sub-topic progress: 5/11
#
# 📖 Processing sub-topic: 1.5 Adding Manure  and Fertilisers
# ✅ Generated 5 Q&A pairs for 1.5 Adding Manure  and Fertilisers
#
# 📍 Sub-topic progress: 6/11
#
# 📖 Processing sub-topic: 1.6 Irrigation
# ✅ Generated 5 Q&A pairs for 1.6 Irrigation
#
# 📍 Sub-topic progress: 7/11
#
# 📖 Processing sub-topic: 1.7 Protection from Weeds
# ✅ Generated 5 Q&A pairs for 1.7 Protection from Weeds
#
# 📍 Sub-topic progress: 8/11
#
# 📖 Processing sub-topic: 1.8 Harvesting
# ✅ Generated 5 Q&A pairs for 1.8 Harvesting
#
# 📍 Sub-topic progress: 9/11
#
# 📖 Processing sub-topic: 1.9 Storage
# ✅ Generated 5 Q&A pairs for 1.9 Storage
#
# 📍 Sub-topic progress: 10/11
#
# 📖 Processing sub-topic: 1.10 Food from Animals
# ✅ Generated 5 Q&A pairs for 1.10 Food from Animals
#
# 📍 Sub-topic progress: 11/11
#
# 📖 Processing sub-topic: 1.10 Food from Animals
# ✅ Generated 5 Q&A pairs for 1.10 Food from Animals
#
# 📚 Processing main topic: CROP PRODUCTION   AND MANAGEMENT
# 📋 Combining 11 sub-topics
# ✅ Generated 20 Q&A pairs for topic CROP PRODUCTION   AND MANAGEMENT
#
# 🎯 Processing main topic: MICROORGANISMS : FRIEND   AND FOE
#    └── Contains 8 sub-topics
#
# 📍 Sub-topic progress: 1/8
#
# 📖 Processing sub-topic: 2.1 Microorganisms
# ✅ Generated 5 Q&A pairs for 2.1 Microorganisms
#
# 📍 Sub-topic progress: 2/8
#
# 📖 Processing sub-topic: 2.2 Where do Microorganisms Live?
# ✅ Generated 5 Q&A pairs for 2.2 Where do Microorganisms Live?
#
# 📍 Sub-topic progress: 3/8
#
# 📖 Processing sub-topic: 2.3 Microorganisms and Us
# ✅ Generated 5 Q&A pairs for 2.3 Microorganisms and Us
#
# 📍 Sub-topic progress: 4/8
#
# 📖 Processing sub-topic: 2.4 Harmful Microorganisms
# ✅ Generated 5 Q&A pairs for 2.4 Harmful Microorganisms
#
# 📍 Sub-topic progress: 5/8
#
# 📖 Processing sub-topic: 2.5 Food Preservation
# ✅ Generated 5 Q&A pairs for 2.5 Food Preservation
#
# 📍 Sub-topic progress: 6/8
#
# 📖 Processing sub-topic: 2.6 Nitrogen Fixation
# ✅ Generated 5 Q&A pairs for 2.6 Nitrogen Fixation
#
# 📍 Sub-topic progress: 7/8
#
# 📖 Processing sub-topic: 2.7 Nitrogen cycle
# ✅ Generated 5 Q&A pairs for 2.7 Nitrogen cycle
#
# 📍 Sub-topic progress: 8/8
#
# 📖 Processing sub-topic: 2.7 Nitrogen cycle
# ✅ Generated 5 Q&A pairs for 2.7 Nitrogen cycle
#
# 📚 Processing main topic: MICROORGANISMS : FRIEND   AND FOE
# 📋 Combining 8 sub-topics
# Attempt 1 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# Attempt 2 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# Attempt 3 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# ✅ Generated 20 Q&A pairs for topic MICROORGANISMS : FRIEND   AND FOE
#
# 🎯 Processing main topic: SYNTHETIC FIBRES   AND PLASTICS
#    └── Contains 7 sub-topics
#
# 📍 Sub-topic progress: 1/7
#
# 📖 Processing sub-topic: 3.1 What are Synthetic Fibres?
# ✅ Generated 5 Q&A pairs for 3.1 What are Synthetic Fibres?
#
# 📍 Sub-topic progress: 2/7
#
# 📖 Processing sub-topic: 3.2 Types of Synthetic Fibres
# ✅ Generated 5 Q&A pairs for 3.2 Types of Synthetic Fibres
#
# 📍 Sub-topic progress: 3/7
#
# 📖 Processing sub-topic: 3.3 Characteristics of Synthetic Fibres
# ✅ Generated 5 Q&A pairs for 3.3 Characteristics of Synthetic Fibres
#
# 📍 Sub-topic progress: 4/7
#
# 📖 Processing sub-topic: 3.4 Plastics
# ✅ Generated 5 Q&A pairs for 3.4 Plastics
#
# 📍 Sub-topic progress: 5/7
#
# 📖 Processing sub-topic: 3.5 Plastics as Materials of Choice
# ✅ Generated 5 Q&A pairs for 3.5 Plastics as Materials of Choice
#
# 📍 Sub-topic progress: 6/7
#
# 📖 Processing sub-topic: 3.6 Plastics and the Environment
# ✅ Generated 5 Q&A pairs for 3.6 Plastics and the Environment
#
# 📍 Sub-topic progress: 7/7
#
# 📖 Processing sub-topic: 3.6 Plastics and the Environment
# ✅ Generated 5 Q&A pairs for 3.6 Plastics and the Environment
#
# 📚 Processing main topic: SYNTHETIC FIBRES   AND PLASTICS
# 📋 Combining 7 sub-topics
# Attempt 1 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# Attempt 2 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# Attempt 3 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# ✅ Generated 25 Q&A pairs for topic SYNTHETIC FIBRES   AND PLASTICS
#
# 🎯 Processing main topic: MATERIALS : METALS   AND NON-METALS
#    └── Contains 4 sub-topics
#
# 📍 Sub-topic progress: 1/4
#
# 📖 Processing sub-topic: 4.1 Physical Properties of Metals and Non-metals
# ✅ Generated 5 Q&A pairs for 4.1 Physical Properties of Metals and Non-metals
#
# 📍 Sub-topic progress: 2/4
#
# 📖 Processing sub-topic: 4.2 Chemical Properties of Metals and Non-metals
# ✅ Generated 5 Q&A pairs for 4.2 Chemical Properties of Metals and Non-metals
#
# 📍 Sub-topic progress: 3/4
#
# 📖 Processing sub-topic: 4.3 Uses of Metals and Non-metals
# ✅ Generated 5 Q&A pairs for 4.3 Uses of Metals and Non-metals
#
# 📍 Sub-topic progress: 4/4
#
# 📖 Processing sub-topic: 4.3 Uses of Metals and Non-metals
# ✅ Generated 5 Q&A pairs for 4.3 Uses of Metals and Non-metals
#
# 📚 Processing main topic: MATERIALS : METALS   AND NON-METALS
# 📋 Combining 4 sub-topics
# Attempt 1 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# Attempt 2 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# Attempt 3 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# ✅ Generated 20 Q&A pairs for topic MATERIALS : METALS   AND NON-METALS
#
# 🎯 Processing main topic: COAL   AND PETROLEUM
#    └── Contains 5 sub-topics
#
# 📍 Sub-topic progress: 1/5
#
# 📖 Processing sub-topic: 5.1 Coal
# ✅ Generated 5 Q&A pairs for 5.1 Coal
#
# 📍 Sub-topic progress: 2/5
#
# 📖 Processing sub-topic: 5.2 Petroleum
# ✅ Generated 5 Q&A pairs for 5.2 Petroleum
#
# 📍 Sub-topic progress: 3/5
#
# 📖 Processing sub-topic: 5.3 Natural Gas
# ✅ Generated 5 Q&A pairs for 5.3 Natural Gas
#
# 📍 Sub-topic progress: 4/5
#
# 📖 Processing sub-topic: 5.4 Some Natural Resources are Limited
# ✅ Generated 5 Q&A pairs for 5.4 Some Natural Resources are Limited
#
# 📍 Sub-topic progress: 5/5
#
# 📖 Processing sub-topic: 5.4 Some Natural Resources are Limited
# ✅ Generated 5 Q&A pairs for 5.4 Some Natural Resources are Limited
#
# 📚 Processing main topic: COAL   AND PETROLEUM
# 📋 Combining 5 sub-topics
# Attempt 1 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# ✅ Generated 20 Q&A pairs for topic COAL   AND PETROLEUM
#
# 🎯 Processing main topic: COMBUSTION   AND FLAME
#    └── Contains 8 sub-topics
#
# 📍 Sub-topic progress: 1/8
#
# 📖 Processing sub-topic: 6.1 What is Combustion?
# ✅ Generated 5 Q&A pairs for 6.1 What is Combustion?
#
# 📍 Sub-topic progress: 2/8
#
# 📖 Processing sub-topic: 6.2 How Do We Control Fire?
# ✅ Generated 5 Q&A pairs for 6.2 How Do We Control Fire?
#
# 📍 Sub-topic progress: 3/8
#
# 📖 Processing sub-topic: 6.3 Types of Combustion
# ✅ Generated 5 Q&A pairs for 6.3 Types of Combustion
#
# 📍 Sub-topic progress: 4/8
#
# 📖 Processing sub-topic: 6.4 Flame
# ✅ Generated 5 Q&A pairs for 6.4 Flame
#
# 📍 Sub-topic progress: 5/8
#
# 📖 Processing sub-topic: 6.5 Structure of a Flame
# ✅ Generated 5 Q&A pairs for 6.5 Structure of a Flame
#
# 📍 Sub-topic progress: 6/8
#
# 📖 Processing sub-topic: 6.6 What is a Fuel?
# ✅ Generated 5 Q&A pairs for 6.6 What is a Fuel?
#
# 📍 Sub-topic progress: 7/8
#
# 📖 Processing sub-topic: 6.7 Fuel Efficiency
# ✅ Generated 5 Q&A pairs for 6.7 Fuel Efficiency
#
# 📍 Sub-topic progress: 8/8
#
# 📖 Processing sub-topic: 6.7 Fuel Efficiency
# ✅ Generated 5 Q&A pairs for 6.7 Fuel Efficiency
#
# 📚 Processing main topic: COMBUSTION   AND FLAME
# 📋 Combining 8 sub-topics
# Attempt 1 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# ✅ Generated 20 Q&A pairs for topic COMBUSTION   AND FLAME
#
# 🎯 Processing main topic: CONSERVATION   OF PLANTS   AND ANIMALS
#    └── Contains 13 sub-topics
#
# 📍 Sub-topic progress: 1/13
#
# 📖 Processing sub-topic: 7.2 Consequences of Deforestation
# ✅ Generated 5 Q&A pairs for 7.2 Consequences of Deforestation
#
# 📍 Sub-topic progress: 2/13
#
# 📖 Processing sub-topic: 7.1 Deforestation and Its Causes
# ✅ Generated 5 Q&A pairs for 7.1 Deforestation and Its Causes
#
# 📍 Sub-topic progress: 3/13
#
# 📖 Processing sub-topic: 7.3 Conservation of Forest and Wildlife
# ✅ Generated 5 Q&A pairs for 7.3 Conservation of Forest and Wildlife
#
# 📍 Sub-topic progress: 4/13
#
# 📖 Processing sub-topic: 7.4 Biosphere Reserve
# ✅ Generated 5 Q&A pairs for 7.4 Biosphere Reserve
#
# 📍 Sub-topic progress: 5/13
#
# 📖 Processing sub-topic: 7.5  Flora and Fauna
# ✅ Generated 5 Q&A pairs for 7.5  Flora and Fauna
#
# 📍 Sub-topic progress: 6/13
#
# 📖 Processing sub-topic: 7.6 Endemic Species
# ✅ Generated 5 Q&A pairs for 7.6 Endemic Species
#
# 📍 Sub-topic progress: 7/13
#
# 📖 Processing sub-topic: 7.7 Wildlife Sanctuary
# ✅ Generated 5 Q&A pairs for 7.7 Wildlife Sanctuary
#
# 📍 Sub-topic progress: 8/13
#
# 📖 Processing sub-topic: 7.8  National Park
# ✅ Generated 5 Q&A pairs for 7.8  National Park
#
# 📍 Sub-topic progress: 9/13
#
# 📖 Processing sub-topic: 7.9 Red Data Book
# ✅ Generated 5 Q&A pairs for 7.9 Red Data Book
#
# 📍 Sub-topic progress: 10/13
#
# 📖 Processing sub-topic: 7.10  Migration
# ✅ Generated 5 Q&A pairs for 7.10  Migration
#
# 📍 Sub-topic progress: 11/13
#
# 📖 Processing sub-topic: 7.11  Recycling of Paper
# ✅ Generated 5 Q&A pairs for 7.11  Recycling of Paper
#
# 📍 Sub-topic progress: 12/13
#
# 📖 Processing sub-topic: 7.12  Reforestation
# ✅ Generated 5 Q&A pairs for 7.12  Reforestation
#
# 📍 Sub-topic progress: 13/13
#
# 📖 Processing sub-topic: 7.12  Reforestation
# ✅ Generated 5 Q&A pairs for 7.12  Reforestation
#
# 📚 Processing main topic: CONSERVATION   OF PLANTS   AND ANIMALS
# 📋 Combining 13 sub-topics
# ✅ Generated 25 Q&A pairs for topic CONSERVATION   OF PLANTS   AND ANIMALS
#
# 🎯 Processing main topic: CELL — STRUCTURE   AND FUNCTIONS
#    └── Contains 7 sub-topics
#
# 📍 Sub-topic progress: 1/7
#
# 📖 Processing sub-topic: 8.1 Discovery of the Cell
# ✅ Generated 5 Q&A pairs for 8.1 Discovery of the Cell
#
# 📍 Sub-topic progress: 2/7
#
# 📖 Processing sub-topic: 8.2 The Cell
# ✅ Generated 5 Q&A pairs for 8.2 The Cell
#
# 📍 Sub-topic progress: 3/7
#
# 📖 Processing sub-topic: 8.3 Organisms show Variety in Cell Number, Shape and Size
# ✅ Generated 5 Q&A pairs for 8.3 Organisms show Variety in Cell Number, Shape and Size
#
# 📍 Sub-topic progress: 4/7
#
# 📖 Processing sub-topic: 8.4 Cell Structure and Function
# ✅ Generated 5 Q&A pairs for 8.4 Cell Structure and Function
#
# 📍 Sub-topic progress: 5/7
#
# 📖 Processing sub-topic: 8.5 Parts of the Cell
# ✅ Generated 5 Q&A pairs for 8.5 Parts of the Cell
#
# 📍 Sub-topic progress: 6/7
#
# 📖 Processing sub-topic: 8.6 Comparison of Plant and Animal Cells
# ✅ Generated 5 Q&A pairs for 8.6 Comparison of Plant and Animal Cells
#
# 📍 Sub-topic progress: 7/7
#
# 📖 Processing sub-topic: 8.6 Comparison of Plant and Animal Cells
# ✅ Generated 5 Q&A pairs for 8.6 Comparison of Plant and Animal Cells
#
# 📚 Processing main topic: CELL — STRUCTURE   AND FUNCTIONS
# 📋 Combining 7 sub-topics
# ✅ Generated 25 Q&A pairs for topic CELL — STRUCTURE   AND FUNCTIONS
#
# 🎯 Processing main topic: REPRODUCTION   IN ANIMALS
#    └── Contains 4 sub-topics
#
# 📍 Sub-topic progress: 1/4
#
# 📖 Processing sub-topic: 9.1 Modes of Reproduction
# ✅ Generated 5 Q&A pairs for 9.1 Modes of Reproduction
#
# 📍 Sub-topic progress: 2/4
#
# 📖 Processing sub-topic: 9.2 Sexual Reproduction
# ✅ Generated 5 Q&A pairs for 9.2 Sexual Reproduction
#
# 📍 Sub-topic progress: 3/4
#
# 📖 Processing sub-topic: 9.3 Asexual Reproduction
# ✅ Generated 5 Q&A pairs for 9.3 Asexual Reproduction
#
# 📍 Sub-topic progress: 4/4
#
# 📖 Processing sub-topic: 9.3 Asexual Reproduction
# ✅ Generated 5 Q&A pairs for 9.3 Asexual Reproduction
#
# 📚 Processing main topic: REPRODUCTION   IN ANIMALS
# 📋 Combining 4 sub-topics
# ✅ Generated 20 Q&A pairs for topic REPRODUCTION   IN ANIMALS
#
# 🎯 Processing main topic: REACHING   THE AGE   OF ADOLESCENCE
#    └── Contains 11 sub-topics
#
# 📍 Sub-topic progress: 1/11
#
# 📖 Processing sub-topic: 10.1 Adolescence and Puberty
# ✅ Generated 5 Q&A pairs for 10.1 Adolescence and Puberty
#
# 📍 Sub-topic progress: 2/11
#
# 📖 Processing sub-topic: 10.2 Changes at Puberty
# ✅ Generated 5 Q&A pairs for 10.2 Changes at Puberty
#
# 📍 Sub-topic progress: 3/11
#
# 📖 Processing sub-topic: 10.3 Secondary Sexual Characters
# ✅ Generated 5 Q&A pairs for 10.3 Secondary Sexual Characters
#
# 📍 Sub-topic progress: 4/11
#
# 📖 Processing sub-topic: 10.4 Role of Hormones in Initiating Reproductive Function
# ✅ Generated 5 Q&A pairs for 10.4 Role of Hormones in Initiating Reproductive Function
#
# 📍 Sub-topic progress: 5/11
#
# 📖 Processing sub-topic: 10.5 Reproductive Phase of Life in Humans
# ✅ Generated 5 Q&A pairs for 10.5 Reproductive Phase of Life in Humans
#
# 📍 Sub-topic progress: 6/11
#
# 📖 Processing sub-topic: 10.6 How is the Sex of the Baby Determined?
# ✅ Generated 5 Q&A pairs for 10.6 How is the Sex of the Baby Determined?
#
# 📍 Sub-topic progress: 7/11
#
# 📖 Processing sub-topic: 10.7 Hormones other than Sex Hormones
# ✅ Generated 5 Q&A pairs for 10.7 Hormones other than Sex Hormones
#
# 📍 Sub-topic progress: 8/11
#
# 📖 Processing sub-topic: 10.8 Role of Hormones in Completing the Life History of Insects and Frogs
# ✅ Generated 5 Q&A pairs for 10.8 Role of Hormones in Completing the Life History of Insects and Frogs
#
# 📍 Sub-topic progress: 9/11
#
# 📖 Processing sub-topic: 10.9 Reproductive Health
# ✅ Generated 5 Q&A pairs for 10.9 Reproductive Health
#
# 📍 Sub-topic progress: 10/11
#
# 📖 Processing sub-topic: Say “NO” to Drugs
# ✅ Generated 5 Q&A pairs for Say “NO” to Drugs
#
# 📍 Sub-topic progress: 11/11
#
# 📖 Processing sub-topic: Say “NO” to Drugs
# ✅ Generated 5 Q&A pairs for Say “NO” to Drugs
#
# 📚 Processing main topic: REACHING   THE AGE   OF ADOLESCENCE
# 📋 Combining 11 sub-topics
# ✅ Generated 20 Q&A pairs for topic REACHING   THE AGE   OF ADOLESCENCE
#
# 🎯 Processing main topic: FORCE   AND PRESSURE
#    └── Contains 11 sub-topics
#
# 📍 Sub-topic progress: 1/11
#
# 📖 Processing sub-topic: 11.1 Force – A Push or a Pull
# ✅ Generated 5 Q&A pairs for 11.1 Force – A Push or a Pull
#
# 📍 Sub-topic progress: 2/11
#
# 📖 Processing sub-topic: 11.2 Forces are due to an Interaction
# ✅ Generated 5 Q&A pairs for 11.2 Forces are due to an Interaction
#
# 📍 Sub-topic progress: 3/11
#
# 📖 Processing sub-topic: 11.3 Exploring Forces
# ✅ Generated 5 Q&A pairs for 11.3 Exploring Forces
#
# 📍 Sub-topic progress: 4/11
#
# 📖 Processing sub-topic: 11.4 A Force can Change the State of Motion
# ✅ Generated 5 Q&A pairs for 11.4 A Force can Change the State of Motion
#
# 📍 Sub-topic progress: 5/11
#
# 📖 Processing sub-topic: 11.5 Force can Change the Shape of an Object
# ✅ Generated 5 Q&A pairs for 11.5 Force can Change the Shape of an Object
#
# 📍 Sub-topic progress: 6/11
#
# 📖 Processing sub-topic: 11.6 Contact Forces
# ✅ Generated 5 Q&A pairs for 11.6 Contact Forces
#
# 📍 Sub-topic progress: 7/11
#
# 📖 Processing sub-topic: 11.7 Non-contact Forces
# ✅ Generated 5 Q&A pairs for 11.7 Non-contact Forces
#
# 📍 Sub-topic progress: 8/11
#
# 📖 Processing sub-topic: 11.8 Pressure
# ✅ Generated 5 Q&A pairs for 11.8 Pressure
#
# 📍 Sub-topic progress: 9/11
#
# 📖 Processing sub-topic: 11.9 Pressure Exerted by Liquids and Gases
# ✅ Generated 5 Q&A pairs for 11.9 Pressure Exerted by Liquids and Gases
#
# 📍 Sub-topic progress: 10/11
#
# 📖 Processing sub-topic: 11.10 Atmospheric Pressure
# ✅ Generated 5 Q&A pairs for 11.10 Atmospheric Pressure
#
# 📍 Sub-topic progress: 11/11
#
# 📖 Processing sub-topic: 11.10 Atmospheric Pressure
# ✅ Generated 5 Q&A pairs for 11.10 Atmospheric Pressure
#
# 📚 Processing main topic: FORCE   AND PRESSURE
# 📋 Combining 11 sub-topics
# Attempt 1 failed: HTTPConnectionPool(host='localhost', port=11434): Read timed out. (read timeout=180)
# ✅ Generated 20 Q&A pairs for topic FORCE   AND PRESSURE
#
# 🎯 Processing main topic: FRICTION
#    └── Contains 7 sub-topics
#
# 📍 Sub-topic progress: 1/7
#
# 📖 Processing sub-topic: 12.1 Force of Friction
# ✅ Generated 5 Q&A pairs for 12.1 Force of Friction
#
# 📍 Sub-topic progress: 2/7
#
# 📖 Processing sub-topic: 12.2 Factors affecting Friction
# ✅ Generated 5 Q&A pairs for 12.2 Factors affecting Friction
#
# 📍 Sub-topic progress: 3/7
#
# 📖 Processing sub-topic: 12.3 Friction : A Necessary Evil
# ✅ Generated 5 Q&A pairs for 12.3 Friction : A Necessary Evil
#
# 📍 Sub-topic progress: 4/7
#
# 📖 Processing sub-topic: 12.4 Increasing and Reducing Friction
# ✅ Generated 5 Q&A pairs for 12.4 Increasing and Reducing Friction
#
# 📍 Sub-topic progress: 5/7
#
# 📖 Processing sub-topic: 12.5 Wheels Reduce Friction
# ✅ Generated 5 Q&A pairs for 12.5 Wheels Reduce Friction
#
# 📍 Sub-topic progress: 6/7
#
# 📖 Processing sub-topic: 12.6 Fluid Friction
# ✅ Generated 5 Q&A pairs for 12.6 Fluid Friction
#
# 📍 Sub-topic progress: 7/7
#
# 📖 Processing sub-topic: 12.6 Fluid Friction
# ✅ Generated 5 Q&A pairs for 12.6 Fluid Friction
#
# 📚 Processing main topic: FRICTION
# 📋 Combining 7 sub-topics
# ✅ Generated 20 Q&A pairs for topic FRICTION
#
# 🎯 Processing main topic: SOUND
#    └── Contains 10 sub-topics
#
# 📍 Sub-topic progress: 1/10
#
# 📖 Processing sub-topic: 13.1 Sound is Produced by a Vibrating Body
# ✅ Generated 5 Q&A pairs for 13.1 Sound is Produced by a Vibrating Body
#
# 📍 Sub-topic progress: 2/10
#
# 📖 Processing sub-topic: 13.2 Sound Produced by Humans
# ✅ Generated 5 Q&A pairs for 13.2 Sound Produced by Humans
#
# 📍 Sub-topic progress: 3/10
#
# 📖 Processing sub-topic: 13.3 Sound Needs a Medium for Propagation
# ✅ Generated 5 Q&A pairs for 13.3 Sound Needs a Medium for Propagation
#
# 📍 Sub-topic progress: 4/10
#
# 📖 Processing sub-topic: 13.4 We Hear Sound through Our Ears
# ✅ Generated 5 Q&A pairs for 13.4 We Hear Sound through Our Ears
#
# 📍 Sub-topic progress: 5/10
#
# 📖 Processing sub-topic: 13.5 Amplitude, Time Period and Frequency of a Vibration
# ✅ Generated 5 Q&A pairs for 13.5 Amplitude, Time Period and Frequency of a Vibration
#
# 📍 Sub-topic progress: 6/10
#
# 📖 Processing sub-topic: 13.6 Audible and Inaudible Sounds
# ✅ Generated 5 Q&A pairs for 13.6 Audible and Inaudible Sounds
#
# 📍 Sub-topic progress: 7/10
#
# 📖 Processing sub-topic: 13.7 Noise and Music
# ✅ Generated 5 Q&A pairs for 13.7 Noise and Music
#
# 📍 Sub-topic progress: 8/10
#
# 📖 Processing sub-topic: 13.8 Noise Pollution
# ✅ Generated 5 Q&A pairs for 13.8 Noise Pollution
#
# 📍 Sub-topic progress: 9/10
#
# 📖 Processing sub-topic: 13.8 Noise Pollution
# ✅ Generated 5 Q&A pairs for 13.8 Noise Pollution
#
# 📍 Sub-topic progress: 10/10
#
# 📖 Processing sub-topic: 13.8 Noise Pollution
# ✅ Generated 5 Q&A pairs for 13.8 Noise Pollution
#
# 📚 Processing main topic: SOUND
# 📋 Combining 10 sub-topics
# ✅ Generated 20 Q&A pairs for topic SOUND
#
# 🎯 Processing main topic: CURRENT
#    └── Contains 4 sub-topics
#
# 📍 Sub-topic progress: 1/4
#
# 📖 Processing sub-topic: 14.1 Do Liquids Conduct Electricity?
# ✅ Generated 5 Q&A pairs for 14.1 Do Liquids Conduct Electricity?
#
# 📍 Sub-topic progress: 2/4
#
# 📖 Processing sub-topic: 14.2 Chemical Effects of Electric Current
# ✅ Generated 5 Q&A pairs for 14.2 Chemical Effects of Electric Current
#
# 📍 Sub-topic progress: 3/4
#
# 📖 Processing sub-topic: 14.3 Electroplating
# ✅ Generated 5 Q&A pairs for 14.3 Electroplating
#
# 📍 Sub-topic progress: 4/4
#
# 📖 Processing sub-topic: 14.3 Electroplating
# ✅ Generated 5 Q&A pairs for 14.3 Electroplating
#
# 📚 Processing main topic: CURRENT
# 📋 Combining 4 sub-topics
# ✅ Generated 20 Q&A pairs for topic CURRENT
#
# 🎯 Processing main topic: SOME NATURAL PHENOMENA
#    └── Contains 8 sub-topics
#
# 📍 Sub-topic progress: 1/8
#
# 📖 Processing sub-topic: 15.1 Lightning
# ✅ Generated 5 Q&A pairs for 15.1 Lightning
#
# 📍 Sub-topic progress: 2/8
#
# 📖 Processing sub-topic: 15.2 Charging by Rubbing
# ✅ Generated 5 Q&A pairs for 15.2 Charging by Rubbing
#
# 📍 Sub-topic progress: 3/8
#
# 📖 Processing sub-topic: 15.3 Types of Charges and Their Interaction
# ✅ Generated 5 Q&A pairs for 15.3 Types of Charges and Their Interaction
#
# 📍 Sub-topic progress: 4/8
#
# 📖 Processing sub-topic: 15.4 Transfer of Charge
# ✅ Generated 5 Q&A pairs for 15.4 Transfer of Charge
#
# 📍 Sub-topic progress: 5/8
#
# 📖 Processing sub-topic: 15.5 The Story of Lightning
# ✅ Generated 5 Q&A pairs for 15.5 The Story of Lightning
#
# 📍 Sub-topic progress: 6/8
#
# 📖 Processing sub-topic: 15.6 Lightning Safety
# ✅ Generated 5 Q&A pairs for 15.6 Lightning Safety
#
# 📍 Sub-topic progress: 7/8
#
# 📖 Processing sub-topic: 15.7 Earthquakes
# ✅ Generated 5 Q&A pairs for 15.7 Earthquakes
#
# 📍 Sub-topic progress: 8/8
#
# 📖 Processing sub-topic: 15.7 Earthquakes
# ✅ Generated 5 Q&A pairs for 15.7 Earthquakes
#
# 📚 Processing main topic: SOME NATURAL PHENOMENA
# 📋 Combining 8 sub-topics
# ✅ Generated 20 Q&A pairs for topic SOME NATURAL PHENOMENA
#
# 🎯 Processing main topic: LIGHT
#    └── Contains 11 sub-topics
#
# 📍 Sub-topic progress: 1/11
#
# 📖 Processing sub-topic: 16.1 What makes Things Visible
# ✅ Generated 5 Q&A pairs for 16.1 What makes Things Visible
#
# 📍 Sub-topic progress: 2/11
#
# 📖 Processing sub-topic: 16.2 Laws of Reflection
# ✅ Generated 5 Q&A pairs for 16.2 Laws of Reflection
#
# 📍 Sub-topic progress: 3/11
#
# 📖 Processing sub-topic: 16.3 Regular and Diffused Reflection
# ✅ Generated 5 Q&A pairs for 16.3 Regular and Diffused Reflection
#
# 📍 Sub-topic progress: 4/11
#
# 📖 Processing sub-topic: 16.4 Reflected Light Can be Reflected Again
# ✅ Generated 5 Q&A pairs for 16.4 Reflected Light Can be Reflected Again
#
# 📍 Sub-topic progress: 5/11
#
# 📖 Processing sub-topic: 16.5 Multiple Images
# ✅ Generated 5 Q&A pairs for 16.5 Multiple Images
#
# 📍 Sub-topic progress: 6/11
#
# 📖 Processing sub-topic: 16.6 Sunlight — White or Coloured
# ✅ Generated 5 Q&A pairs for 16.6 Sunlight — White or Coloured
#
# 📍 Sub-topic progress: 7/11
#
# 📖 Processing sub-topic: 16.7 What is inside Our Eyes?
# ✅ Generated 5 Q&A pairs for 16.7 What is inside Our Eyes?
#
# 📍 Sub-topic progress: 8/11
#
# 📖 Processing sub-topic: 16.8 Care of the Eyes
# ✅ Generated 5 Q&A pairs for 16.8 Care of the Eyes
#
# 📍 Sub-topic progress: 9/11
#
# 📖 Processing sub-topic: 16.9 Visually Impaired Persons Can Read and Write
# ✅ Generated 5 Q&A pairs for 16.9 Visually Impaired Persons Can Read and Write
#
# 📍 Sub-topic progress: 10/11
#
# 📖 Processing sub-topic: 16.10 What is the Braille System?
# ✅ Generated 5 Q&A pairs for 16.10 What is the Braille System?
#
# 📍 Sub-topic progress: 11/11
#
# 📖 Processing sub-topic: 16.10 What is the Braille System?
# ✅ Generated 5 Q&A pairs for 16.10 What is the Braille System?
#
# 📚 Processing main topic: LIGHT
# 📋 Combining 11 sub-topics
# ✅ Generated 25 Q&A pairs for topic LIGHT
#
# 🎯 Processing main topic: STARS   AND   THE SOLAR SYSTEM
#    └── Contains 6 sub-topics
#
# 📍 Sub-topic progress: 1/6
#
# 📖 Processing sub-topic: 17.1 The Moon
# ✅ Generated 5 Q&A pairs for 17.1 The Moon
#
# 📍 Sub-topic progress: 2/6
#
# 📖 Processing sub-topic: 17.2 The Stars
# ✅ Generated 5 Q&A pairs for 17.2 The Stars
#
# 📍 Sub-topic progress: 3/6
#
# 📖 Processing sub-topic: 17.3 Constellations
# ✅ Generated 5 Q&A pairs for 17.3 Constellations
#
# 📍 Sub-topic progress: 4/6
#
# 📖 Processing sub-topic: 17.4 The Solar System
# ✅ Generated 5 Q&A pairs for 17.4 The Solar System
#
# 📍 Sub-topic progress: 5/6
#
# 📖 Processing sub-topic: 17.5 Some Other Members of the Solar System
# ✅ Generated 5 Q&A pairs for 17.5 Some Other Members of the Solar System
#
# 📍 Sub-topic progress: 6/6
#
# 📖 Processing sub-topic: 17.5 Some Other Members of the Solar System
# ✅ Generated 5 Q&A pairs for 17.5 Some Other Members of the Solar System
#
# 📚 Processing main topic: STARS   AND   THE SOLAR SYSTEM
# 📋 Combining 6 sub-topics
# ✅ Generated 20 Q&A pairs for topic STARS   AND   THE SOLAR SYSTEM
#
# 🎯 Processing main topic: POLLUTION   OF AIR   AND WATER
#    └── Contains 2 sub-topics
#
# 📍 Sub-topic progress: 1/2
#
# 📖 Processing sub-topic: 18.1 Air Pollution
# ✅ Generated 5 Q&A pairs for 18.1 Air Pollution
#
# 📍 Sub-topic progress: 2/2
#
# 📖 Processing sub-topic: 18.2 How does Air Get Polluted?
# ✅ Generated 5 Q&A pairs for 18.2 How does Air Get Polluted?
#
# 📚 Processing main topic: POLLUTION   OF AIR   AND WATER
# 📋 Combining 2 sub-topics
# ✅ Generated 30 Q&A pairs for topic POLLUTION   OF AIR   AND WATER
#
# 🎉 SUCCESS!
# ✅ Processed 137 sub-topics successfully
# ✅ Processed 18 main topics successfully
# 💾 Saved to: /Users/saikumarallaka/kaggle/gemma_3n_impact_challenge/datasets/education/education_qa_dataset.json
# 📊 Total Q&A pairs generated: 1075

# %%
1
# Out:
# 1
